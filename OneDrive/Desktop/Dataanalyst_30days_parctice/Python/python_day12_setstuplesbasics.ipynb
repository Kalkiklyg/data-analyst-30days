# %%
# day12_sets_tuples.py
a = {1,2,3,4}
b = {3,4,5}
print("union:", a.union(b))
print("intersection:", a & b)
print("difference a-b:", a - b)

coords = (10, 20)
x, y = coords
print("x:", x, "y:", y)
# Out:
# union: {1, 2, 3, 4, 5}
# intersection: {3, 4}
# difference a-b: {1, 2}
# x: 10 y: 20
